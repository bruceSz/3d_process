# %%
#1.read data
import os
p_dir = "./dataset/modelnet40_normal_resampled"
classes = os.listdir(p_dir)
print("total classes ", classes)
print("number of classes ", len(classes))

#deprecated
def get_pcd_per_cls_deprecate(p_dir):
        classes = os.listdir(p_dir)
        for cls_path in classes:
            cls_path = os.path.join(p_dir, cls_path)
            pcd_per_cls = os.listdir(cls_path)[0]
            pcd_path = os.path.join(cls_path, pcd_per_class)
            print(pcd_path)
            
            
def get_key(p):
    return p.split("/")[0]


def get_pcd_cls(p_dir):
    m_ = {}
    listf = os.path.join(p_dir, "filelist.txt")
    with open(listf,"r") as f:
        l = f.readlines()
        l = list(map(lambda x:x.strip(), l))
        for i in l :
            key = get_key(i)
            if not key in m_:
                m_[key] = os.path.join(p_dir, i)
    return m_
    
m_ = get_pcd_cls(p_dir)
for k in m_:
    print("cls: ", k, " : ", m_[k])
print(len(m_))
# Out:
# total classes  ['tent', 'flower_pot', 'bed', 'monitor', 'night_stand', 'airplane', 'bottle', 'filelist.txt', 'laptop', 'keyboard', 'car', 'modelnet10_train.txt', 'modelnet10_test.txt', 'toilet', 'vase', 'wardrobe', 'person', 'tv_stand', 'plant', 'modelnet10_shape_names.txt', 'piano', 'curtain', 'sofa', 'guitar', 'cup', 'bathtub', 'cone', 'modelnet40_shape_names.txt', 'range_hood', 'lamp', 'sink', 'modelnet40_train.txt', 'dresser', 'bowl', 'bookshelf', 'mantel', 'chair', 'radio', 'stool', 'xbox', 'glass_box', 'modelnet40_test.txt', 'table', 'door', 'bench', 'stairs', 'desk']
# number of classes  47
# cls:  airplane  :  ./dataset/modelnet40_normal_resampled/airplane/airplane_0001.txt
# cls:  bathtub  :  ./dataset/modelnet40_normal_resampled/bathtub/bathtub_0001.txt
# cls:  bed  :  ./dataset/modelnet40_normal_resampled/bed/bed_0001.txt
# cls:  bench  :  ./dataset/modelnet40_normal_resampled/bench/bench_0001.txt
# cls:  bookshelf  :  ./dataset/modelnet40_normal_resampled/bookshelf/bookshelf_0001.txt
# cls:  bottle  :  ./dataset/modelnet40_normal_resampled/bottle/bottle_0001.txt
# cls:  bowl  :  ./dataset/modelnet40_normal_resampled/bowl/bowl_0001.txt
# cls:  car  :  ./dataset/modelnet40_normal_resampled/car/car_0001.txt
# cls:  chair  :  ./dataset/modelnet40_normal_resampled/chair/chair_0001.txt
# cls:  cone  :  ./dataset/modelnet40_normal_resampled/cone/cone_0001.txt
# cls:  cup  :  ./dataset/modelnet40_normal_resampled/cup/cup_0001.txt
# cls:  curtain  :  ./dataset/modelnet40_normal_resampled/curtain/curtain_0001.txt
# cls:  desk  :  ./dataset/modelnet40_normal_resampled/desk/desk_0001.txt
# cls:  door  :  ./dataset/modelnet40_normal_resampled/door/door_0001.txt
# cls:  dresser  :  ./dataset/modelnet40_normal_resampled/dresser/dresser_0001.txt
# cls:  flower_pot  :  ./dataset/modelnet40_normal_resampled/flower_pot/flower_pot_0001.txt
# cls:  glass_box  :  ./dataset/modelnet40_normal_resampled/glass_box/glass_box_0001.txt
# cls:  guitar  :  ./dataset/modelnet40_normal_resampled/guitar/guitar_0001.txt
# cls:  keyboard  :  ./dataset/modelnet40_normal_resampled/keyboard/keyboard_0001.txt
# cls:  lamp  :  ./dataset/modelnet40_normal_resampled/lamp/lamp_0001.txt
# cls:  laptop  :  ./dataset/modelnet40_normal_resampled/laptop/laptop_0001.txt
# cls:  mantel  :  ./dataset/modelnet40_normal_resampled/mantel/mantel_0001.txt
# cls:  monitor  :  ./dataset/modelnet40_normal_resampled/monitor/monitor_0001.txt
# cls:  night_stand  :  ./dataset/modelnet40_normal_resampled/night_stand/night_stand_0001.txt
# cls:  person  :  ./dataset/modelnet40_normal_resampled/person/person_0001.txt
# cls:  piano  :  ./dataset/modelnet40_normal_resampled/piano/piano_0001.txt
# cls:  plant  :  ./dataset/modelnet40_normal_resampled/plant/plant_0001.txt
# cls:  radio  :  ./dataset/modelnet40_normal_resampled/radio/radio_0001.txt
# cls:  range_hood  :  ./dataset/modelnet40_normal_resampled/range_hood/range_hood_0001.txt
# cls:  sink  :  ./dataset/modelnet40_normal_resampled/sink/sink_0001.txt
# cls:  sofa  :  ./dataset/modelnet40_normal_resampled/sofa/sofa_0001.txt
# cls:  stairs  :  ./dataset/modelnet40_normal_resampled/stairs/stairs_0001.txt
# cls:  stool  :  ./dataset/modelnet40_normal_resampled/stool/stool_0001.txt
# cls:  table  :  ./dataset/modelnet40_normal_resampled/table/table_0001.txt
# cls:  tent  :  ./dataset/modelnet40_normal_resampled/tent/tent_0001.txt
# cls:  toilet  :  ./dataset/modelnet40_normal_resampled/toilet/toilet_0001.txt
# cls:  tv_stand  :  ./dataset/modelnet40_normal_resampled/tv_stand/tv_stand_0001.txt
# cls:  vase  :  ./dataset/modelnet40_normal_resampled/vase/vase_0001.txt
# cls:  wardrobe  :  ./dataset/modelnet40_normal_resampled/wardrobe/wardrobe_0001.txt
# cls:  xbox  :  ./dataset/modelnet40_normal_resampled/xbox/xbox_0001.txt
# 40

# %%
def plot_pcd_from_path(path):
    pts = load_pcd(path)
    import open3d as o3d
    d_pcd = o3d.geometry.PointCloud()
    d_pcd.points = o3d.utility.Vector3dVector(pts[:,0:3])
    #d_pcd.colors = o3d.utility.Vector3dVector(pts[:,3:6])
    o3d.visualization.draw_geometries([d_pcd])

def plot_pcd_from_pts(pts):
    import open3d as o3d
    d_pcd = o3d.geometry.PointCloud()
    d_pcd.points = o3d.utility.Vector3dVector(pts[:,0:3])
    #d_pcd.colors = o3d.utility.Vector3dVector(pts[:,3:6])
    o3d.visualization.draw_geometries([d_pcd])
        
def load_pcd(path):
        import numpy as np
        pts = np.loadtxt(open(path,'r'), delimiter=',' , dtype = np.float32)
        pts = pts.reshape(-1, 6)
        return pts
        #d_pcd = o3d.geometry.PointCloud()
        #d_pcd.points = o3d.utility.Vector3dVector(pts[:,0:3])
        #d_pcd.colors = o3d.utility.Vector3dVector(pts[:,3:6])
        #o3d.visualization.draw_geometries([d_pcd])
        
        
def load_datas(dataset):
    res = {}
    for cls in dataset:
        path = dataset[cls]
        pts = load_pcd(path)
        res[cls] = pts
    return res
        
f = m_["airplane"]
plot_pcd(f)

# %%
# see airplane_origin.png

# %%
da = load_datas(m_)
da.keys()
#plot_pcd(da["airplane"])
# Out:
# dict_keys(['airplane', 'bathtub', 'bed', 'bench', 'bookshelf', 'bottle', 'bowl', 'car', 'chair', 'cone', 'cup', 'curtain', 'desk', 'door', 'dresser', 'flower_pot', 'glass_box', 'guitar', 'keyboard', 'lamp', 'laptop', 'mantel', 'monitor', 'night_stand', 'person', 'piano', 'plant', 'radio', 'range_hood', 'sink', 'sofa', 'stairs', 'stool', 'table', 'tent', 'toilet', 'tv_stand', 'vase', 'wardrobe', 'xbox'])

# %%
import numpy as np
def pca(pts, number_pc= 1):
    print("raw shape",pts.shape)
    assert pts.shape[1] == 3
    X = pts.transpose()
    x_bar = np.sum(X, axis=1)/len(pts)
    print("x_bar",x_bar.transpose())
    print("X shape: ", X.shape)
    center_X = (X.transpose() - x_bar).transpose()
    center_X_t = center_X.transpose()
    print("x_bar_t",center_X_t.shape)
    H = np.matmul( center_X, center_X_t)
    print(H.shape)
    U,s, V = np.linalg.svd(H)
    target_eigen_vs = U[:,:number_pc]
    print(" u shape: ", U.shape)
    print("eigen values: ",s)
    print("target eigen vec shape: ", target_eigen_vs.shape)
    # encode phase
    proj_res = np.matmul(target_eigen_vs.transpose(), X)
    print("low dimension shape",proj_res.shape)
    reconv = np.matmul(target_eigen_vs, proj_res)
    print("reconv shape: ",reconv.shape)
    return reconv.transpose()
    #return pca_res.transpose()
    

target = "bathtub"
print(da[target].shape)
air_plane_pcd = da[target][:,0:3]
print(air_plane_pcd.shape)
res = pca(air_plane_pcd, number_pc = 2)
print(air_plane_pcd[:10,:])
print(res[:10,:])

print("new res shape: ", new_res)
res2 = plot_pcd_from_pts(res)
