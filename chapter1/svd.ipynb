# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
import sys
data_dir = sys.path[0] + "/dataset"
print(data_dir)
# Out:
# /home/zhangs20/git/3d_process/chapter1/dataset

# %%
import os
import PIL 
print(data_dir)
img_path = data_dir + "/" + "sea.jpeg"
print(img_path)
img = mpimg.imread(img_path)
print(img.shape)
plt.imshow(img)
#from IPython.display import Image, display
#display(PIL.Image.fromarray(img))
# Out:
# /home/zhangs20/git/3d_process/chapter1/dataset
# /home/zhangs20/git/3d_process/chapter1/dataset/sea.jpeg
# (1200, 1600, 3)

# %%
img_tmp = img.reshape(1200,1600*3)
U, S, V = np.linalg.svd(img_tmp)
first_n = 500
img1 = (U[:,0:first_n]).dot(np.diag(S[0:first_n])).dot(V[0:first_n,:])
print(type(img1))
#img1 = img1.reshape(168,)
plt.imshow(img1)
#print(img1.shape)#
#img = PIL.Image.fromarray(img1,'RGB')
#plt.imshow(img)
#from PIL import Image
#display(PIL.Image.fromarray(img1))
#from IPython.display import Image, display
#display(img1)
# Out:
# <class 'numpy.ndarray'>

# %%
w, h = 512, 512
data = np.zeros((h, w, 3), dtype=np.uint8)
data[0:256, 0:256] = [255, 0, 0] # red patch in upper left
img = Image.fromarray(data, 'RGB')
#img.save('my.png')
img.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_30881/3718613884.py in <module>
#       2 data = np.zeros((h, w, 3), dtype=np.uint8)
#       3 data[0:256, 0:256] = [255, 0, 0] # red patch in upper left
# ----> 4 img = Image.fromarray(data, 'RGB')
#       5 #img.save('my.png')
#       6 img.show()
#
# AttributeError: type object 'Image' has no attribute 'fromarray'
